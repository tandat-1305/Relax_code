# %% [markdown]
# <a href="https://colab.research.google.com/github/tandat-1305/Relax_code/blob/main/huong_dan_gia_dinh_ANOVA1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# PHÂN TÍCH ANOVA MỘT CHIỀU
#
# Phân tích ANOVA chấp nhận các giả định sau:
#
# (1) Tất cả các nhóm đều độc lập với nhau
#
# (2) Dữ liệu của mỗi nhóm đều tuân theo phân phối chuẩn. Tính chất này có thể được kiểm định bằng phương pháp Shapiro-Wilks.
#
# (3) Phương sai (variance) của các nhóm bằng nhau. Tính chất này có thể được kiểm định bằng phương pháp kiểm định Bartlett hay Levene.
#
# Nếu dữ liệu hiện có thỏa mãn các tính chất trên thì chúng ta mới tiến hành kiểm định ANOVA. Do vậy trước khi tiến hành kiểm định ANOVA, chúng ta cần thực hiện kiểm tra tập dữ liệu cần thỏa mãn 3 tính chất trên.

# %%
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
from scipy.stats import bartlett

# %%
#Bước 1: Hãy tạo một tập dữ liệu mẫu sample_1 với kích thước 100 tuân theo phân phối chuẩn
sample_1 = np.random.normal(100,10,500)
sample_1
# Out:
# array([101.69486185, 100.39712606,  94.09048067, 107.18846634,
#         85.78376563, 106.83758427,  90.9076997 ,  82.76383826,
#         96.35401351,  78.63943723,  87.56660702, 132.20721724,
#         98.78264833, 112.77670946,  82.39349845, 105.80000934,
#        103.58052515,  99.83591539, 109.94064903,  84.46996672,
#         73.48308064,  87.91738959, 100.01868858, 102.53010984,
#         96.91235968,  94.74064439, 115.00961415, 104.61845974,
#         98.97613723, 107.43081814, 102.13623086, 104.87334196,
#        105.77456321, 102.2327136 ,  99.57384882,  75.68815388,
#         97.48042459,  98.92887642, 112.75938613, 109.06207323,
#         91.70736691,  91.17965709, 107.46438996,  98.73555182,
#         92.96522469, 112.62074284, 110.13935585,  92.42306168,
#         96.1799849 , 102.97907684,  94.21300138,  90.37967073,
#         92.97095156, 111.43326815,  96.24090876, 100.88216133,
#         90.35761815, 104.67508589,  96.91046136,  88.05987953,
# ...

# %%
#Bước 2: hãy tạo tập dữ liệu mẫu sample_2 với kích thước 100 tuân theo phân phối Poisson
sample_2 = np.random.poisson(lam=10,size=1000)
sample_2
# Out:
# array([10,  8, 10,  8,  5,  4,  3, 12, 14,  8, 13, 12, 13, 14,  6, 11,  8,
#         6, 14, 14,  5, 11, 16, 13,  9, 15,  9,  9,  9, 17, 10,  7,  9,  9,
#        12,  5, 11,  9,  9,  9,  4, 15, 10, 13,  8, 14,  6, 13, 13, 10,  8,
#        10, 11,  4, 16, 10, 13, 10,  6, 13, 15,  6, 11, 11,  9,  9, 11, 11,
#        10,  7,  3, 11,  9, 11, 10,  7,  9,  9, 11,  6, 15,  9,  9,  8,  7,
#         5, 12,  4, 10,  9, 13, 14,  9,  9, 11, 15,  9,  7,  7, 11,  9,  5,
#        12,  5,  6, 13, 13, 14,  5, 10,  9, 14,  7, 12,  8, 11, 11,  5,  9,
#         6,  8,  9,  8, 12, 11, 13,  7,  7, 14, 10, 12, 16,  7, 11, 14,  7,
#         6, 10, 12, 10,  8, 16,  9,  8,  8,  8, 10,  9,  8,  5,  9, 18, 11,
#        13,  9,  9, 12, 15,  5,  9,  5,  8,  7, 12,  9, 10, 11, 16,  9,  6,
#        12, 11,  7, 12, 10,  8, 16, 11,  9,  7, 13, 10, 11,  8, 12,  8, 11,
#        14, 11, 15, 13,  9, 10, 12, 14,  6,  9,  9,  5,  9,  8,  9, 11, 10,
# ...

# %% [markdown]
# Hãy tham khảo các hướng dẫn sau để kiểm định tính chất thứ 2 bằng phương pháp Shapiro-Wilks đối với sample_1 và sample_2
#
# (1) [Tài liệu tham khảo scipy](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.shapiro.html)
#
# (2) [Hướng dẫn cụ thể của statology](https://www.statology.org/shapiro-wilk-test-python/)

# %%
#Code kiểm định tính chất thứ 2 của sample_1 và sample_2
print("Shapiro-Wilk theo phân phối chuẩnchuẩn")
sw_1 = stats.shapiro(sample_1)
print("statistic = ",sw_1[0],
      "p value = ",sw_1[1]
      )
print("Shapiro-Wilk theo phân phôi Poisson")
sw_2 = stats.shapiro(sample_2)
print("statistic = ",sw_2[0],
      "p value = ",sw_2[1]
      )
# Out:
# Shapiro-Wilk theo phân phối chuẩnchuẩn
# statistic =  0.9981032013893127 p value =  0.859951913356781
# Shapiro-Wilk theo phân phôi Poisson
# statistic =  0.9847236275672913 p value =  1.0116768756063266e-08

# %% [markdown]
# Hãy tham khảo các hướng dẫn sau để kiểm định tính chất thứ 3 bằng kiểm định Bartlett hoặc kiểm định Levene
#
# (1) [Hướng dẫn tổng quát](https://www.marsja.se/levenes-bartletts-test-of-equality-homogeneity-of-variance-in-python/)
#
# (2) [Hướng dẫn ở stackoverflow](https://stackoverflow.com/questions/36141254/how-to-test-for-homoscedasticity-having-the-same-population-variance-in-python)
#
# (3) Sử dụng bài giảng về kiểm định Bartlett và Levene ở buổi trước

# %%
#Code kiểm định tính đồng nhất về phương sai của các nhóm

# %%
sw_3 = stats.levene(sample_1,sample_2)[1]
if sw_3 > 0.05:
    print('Phương sai bằng nhau')
else:
    print('Phương sai không bằng nhau')
# Out:
# Phương sai không bằng nhau
